# %%
# Consumed Endurance GUI
import tkinter as tk
from tkinter import ttk
import math as ma

#overall layout
root=tk.Tk()
root.title("Consumed Endurance GUI")
frame=tk.Frame(root,padx=20,pady=10)
visualizationUi=tk.Frame(frame,borderwidth=2,relief=tk.GROOVE)
modellingUi=ttk.Labelframe(frame,text="Modelling")
frame.grid()
visualizationUi.grid(row=0,column=0,padx=10)
modellingUi.grid(row=0,column=1,padx=10,pady=10)

#male metrics
lengthUpperArm=132
lengthForearm=108
lengthHand=76
angleUpperArm=0
angleForearm=0
angleHand=0
ratioCoMUpperArm=0.452
ratioCoMForearm=0.424
ratioCoMHand=0.397
massUpperArm=2.1
massForearm=1.2
massHand=0.4
global xShoulder
xShoulder=10.0
global yShoulder
yShoulder=100.0
global xElbow
xElbow=90.0
global yElbow
yElbow=160.0
global xWrist
xWrist=170.0
global yWrist
yWrist=220.0
global xFingerTip
xFingerTip=250.0
global yFingerTip
yFingerTip=280.0
global xA
xA=xShoulder*(1-ratioCoMUpperArm)+xElbow*ratioCoMUpperArm
global yA
yA=yShoulder*(1-ratioCoMUpperArm)+yElbow*ratioCoMUpperArm
global xB
xB=xElbow*(1-ratioCoMForearm)+xWrist*ratioCoMForearm
global yB
yB=yElbow*(1-ratioCoMForearm)+yWrist*ratioCoMForearm
global xC
xC=xWrist*(1-ratioCoMHand)+xFingerTip*ratioCoMHand
global yC
yC=yWrist*(1-ratioCoMHand)+yFingerTip*ratioCoMHand
global xD
xD=xB*(1-(massHand/(massForearm+massHand)))+xC*(massHand/(massForearm+massHand))
global yD
yD=yB*(1-(massHand/(massForearm+massHand)))+yC*(massHand/(massForearm+massHand))
global xCoM
xCoM=xA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
global yCoM
yCoM=yA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))

#sliders controlling associated segment angles
def onAngleUpperArmChanged(val):
    angleUpperArm=float(val)
    angleForearm=float(sliderForearm.get())
    angleHand=float(sliderHand.get())
    global xElbow
    xElbow=xShoulder+lengthUpperArm*ma.cos(angleUpperArm*ma.pi/180)
    global yElbow
    yElbow=yShoulder-lengthUpperArm*ma.sin(angleUpperArm*ma.pi/180)
    global xWrist
    xWrist=xElbow+lengthForearm*ma.cos(angleForearm*ma.pi/180)
    global yWrist
    yWrist=yElbow-lengthForearm*ma.sin(angleForearm*ma.pi/180)
    global xFingerTip
    xFingerTip=xWrist+lengthHand*ma.cos(angleHand*ma.pi/180)
    global yFingerTip
    yFingerTip=yWrist-lengthHand*ma.sin(angleHand*ma.pi/180)
    global xA
    xA=xShoulder*(1-ratioCoMUpperArm)+xElbow*ratioCoMUpperArm
    global yA
    yA=yShoulder*(1-ratioCoMUpperArm)+yElbow*ratioCoMUpperArm
    global xB
    xB=xElbow*(1-ratioCoMForearm)+xWrist*ratioCoMForearm
    global yB
    yB=yElbow*(1-ratioCoMForearm)+yWrist*ratioCoMForearm
    global xC
    xC=xWrist*(1-ratioCoMHand)+xFingerTip*ratioCoMHand
    global yC
    yC=yWrist*(1-ratioCoMHand)+yFingerTip*ratioCoMHand
    global xD
    xD=xB*(1-(massHand/(massForearm+massHand)))+xC*(massHand/(massForearm+massHand))
    global yD
    yD=yB*(1-(massHand/(massForearm+massHand)))+yC*(massHand/(massForearm+massHand))
    global xCoM
    xCoM=xA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global yCoM
    yCoM=yA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    canvas.coords(arm,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvas.coords(jointElbow,xElbow-5,yElbow+5,xElbow+5,yElbow-5)
    canvas.coords(jointWrist,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
    canvas.coords(jointFingerTip,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    CoMAnalysis.coords(armAnalysis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
#    CoMAnalysis.coords(jointElbowAnalysis,xElbow-5,yElbow+5,xElbow+5,yElbow-5)
#    CoMAnalysis.coords(jointWristAnalysis,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
#    CoMAnalysis.coords(jointFingerTipAnalysis,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
#    CoMAnalysis.coords(elbowLabel,xElbow,yElbow+10)
#    CoMAnalysis.coords(wristLabel,xWrist,yWrist+10)
#    CoMAnalysis.coords(fingerTipLabel,xFingerTip,yFingerTip+10)
#    CoMAnalysis.coords(aAnalysis,xA-2,yA+2,xA+2,yA-2)
#    CoMAnalysis.coords(bAnalysis,xB-2,yB+2,xB+2,yB-2)
#    CoMAnalysis.coords(cAnalysis,xC-2,yC+2,xC+2,yC-2)
#    CoMAnalysis.coords(aLabel,xA,yA+10)
#    CoMAnalysis.coords(bLabel,xB,yB+10)
#    CoMAnalysis.coords(cLabel,xC,yC+10)
#    CoMAnalysis.coords(abLine,xA,yA,xB,yB)
#    CoMAnalysis.coords(bcLine,xB,yB,xC,yC)

def onAngleForearmChanged(val):
    angleForearm=float(val)
    angleHand=float(sliderHand.get())
    global xWrist
    xWrist=xElbow+lengthForearm*ma.cos(angleForearm*ma.pi/180)
    global yWrist
    yWrist=yElbow-lengthForearm*ma.sin(angleForearm*ma.pi/180)
    global xFingerTip
    xFingerTip=xWrist+lengthHand*ma.cos(angleHand*ma.pi/180)
    global yFingerTip
    yFingerTip=yWrist-lengthHand*ma.sin(angleHand*ma.pi/180)
    global xB
    xB=xElbow*(1-ratioCoMForearm)+xWrist*ratioCoMForearm
    global yB
    yB=yElbow*(1-ratioCoMForearm)+yWrist*ratioCoMForearm
    global xC
    xC=xWrist*(1-ratioCoMHand)+xFingerTip*ratioCoMHand
    global yC
    yC=yWrist*(1-ratioCoMHand)+yFingerTip*ratioCoMHand
    global xD
    xD=xB*(1-(massHand/(massForearm+massHand)))+xC*(massHand/(massForearm+massHand))
    global yD
    yD=yB*(1-(massHand/(massForearm+massHand)))+yC*(massHand/(massForearm+massHand))
    global xCoM
    xCoM=xA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global yCoM
    yCoM=yA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    canvas.coords(arm,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvas.coords(jointWrist,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
    canvas.coords(jointFingerTip,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    CoMAnalysis.coords(armAnalysis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
#    CoMAnalysis.coords(jointWristAnalysis,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
#    CoMAnalysis.coords(jointFingerTipAnalysis,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
#    CoMAnalysis.coords(wristLabel,xWrist,yWrist+10)
#    CoMAnalysis.coords(fingerTipLabel,xFingerTip,yFingerTip+10)
#    CoMAnalysis.coords(bAnalysis,xB-2,yB+2,xB+2,yB-2)
#    CoMAnalysis.coords(cAnalysis,xC-2,yC+2,xC+2,yC-2)
#    CoMAnalysis.coords(bLabel,xB,yB+10)
#    CoMAnalysis.coords(cLabel,xC,yC+10)
#    CoMAnalysis.coords(abLine,xA,yA,xB,yB)
#    CoMAnalysis.coords(bcLine,xB,yB,xC,yC)

def onAngleHandChanged(val):
    angleHand=float(val)
    global xFingerTip
    xFingerTip=xWrist+lengthHand*ma.cos(angleHand*ma.pi/180)
    global yFingerTip
    yFingerTip=yWrist-lengthHand*ma.sin(angleHand*ma.pi/180)
    global xC
    xC=xWrist*(1-ratioCoMHand)+xFingerTip*ratioCoMHand
    global yC
    yC=yWrist*(1-ratioCoMHand)+yFingerTip*ratioCoMHand
    global xD
    xD=xB*(1-(massHand/(massForearm+massHand)))+xC*(massHand/(massForearm+massHand))
    global yD
    yD=yB*(1-(massHand/(massForearm+massHand)))+yC*(massHand/(massForearm+massHand))
    global xCoM
    xCoM=xA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global yCoM
    yCoM=yA*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yD*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    canvas.coords(arm,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvas.coords(jointFingerTip,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    CoMAnalysis.coords(armAnalysis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
#    CoMAnalysis.coords(jointFingerTipAnalysis,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
#    CoMAnalysis.coords(fingerTipLabel,xFingerTip,yFingerTip+10)
#    CoMAnalysis.coords(cAnalysis,xC-2,yC+2,xC+2,yC-2)
#    CoMAnalysis.coords(cLabel,xC,yC+10)
#    CoMAnalysis.coords(abLine,xA,yA,xB,yB)
#    CoMAnalysis.coords(bcLine,xB,yB,xC,yC)

#visualization UI
canvas=tk.Canvas(visualizationUi,bg="white",borderwidth=2,relief=tk.GROOVE)
arm=canvas.create_line(xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
jointShoulder=canvas.create_oval(xShoulder-5,yShoulder+5,xShoulder+5,yShoulder-5)
jointElbow=canvas.create_oval(xElbow-5,yElbow+5,xElbow+5,yElbow-5)
jointWrist=canvas.create_oval(xWrist-5,yWrist+5,xWrist+5,yWrist-5)
jointFingerTip=canvas.create_oval(xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
sliderUpperArm=tk.Scale(visualizationUi,from_=90,to=-90,command=onAngleUpperArmChanged)
sliderForearm=tk.Scale(visualizationUi,from_=90,to=0,command=onAngleForearmChanged)
sliderHand=tk.Scale(visualizationUi,from_=90,to=-90,command=onAngleHandChanged)
angleUpperArmLabel=tk.Label(visualizationUi,text="Upper Arm Angle (°) =")
angleForearmLabel=tk.Label(visualizationUi,text="Forearm Angle (°) =")
angleHandLabel=tk.Label(visualizationUi,text="Hand Angle (°) =")
canvas.grid(row=0,column=0,columnspan=3)
sliderUpperArm.grid(row=1,column=0)
sliderForearm.grid(row=1,column=1)
sliderHand.grid(row=1,column=2)
angleUpperArmLabel.grid(row=2,column=0)
angleForearmLabel.grid(row=2,column=1)
angleHandLabel.grid(row=2,column=2)

#modelling UI
CoMAnalysis=tk.Canvas(modellingUi,borderwidth=2,relief=tk.GROOVE)
CoMAnalysis.grid(row=0,column=0)
armAnalysis=CoMAnalysis.create_line(xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
jointShoulderAnalysis=CoMAnalysis.create_oval(xShoulder-5,yShoulder+5,xShoulder+5,yShoulder-5)
jointElbowAnalysis=CoMAnalysis.create_oval(xElbow-5,yElbow+5,xElbow+5,yElbow-5)
jointWristAnalysis=CoMAnalysis.create_oval(xWrist-5,yWrist+5,xWrist+5,yWrist-5)
jointFingerTipAnalysis=CoMAnalysis.create_oval(xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
shoulderLabel=CoMAnalysis.create_text(xShoulder,yShoulder+10,text="Shoulder")
elbowLabel=CoMAnalysis.create_text(xElbow,yElbow+10,text="Elbow")
wristLabel=CoMAnalysis.create_text(xWrist,yWrist+10,text="Wrist")
fingerTipLabel=CoMAnalysis.create_text(xFingerTip,yFingerTip+10,text="Finger Tip")
aAnalysis=CoMAnalysis.create_oval(xA-2,yA+2,xA+2,yA-2)
bAnalysis=CoMAnalysis.create_oval(xB-2,yB+2,xB+2,yB-2)
cAnalysis=CoMAnalysis.create_oval(xC-2,yC+2,xC+2,yC-2)
dAnalysis=CoMAnalysis.create_oval(xD-2,yD+2,xD+2,yD-2)
CoMAnalysis=CoMAnalysis.create_oval(xCoM-2,yCoM+2,xCoM+2,yCoM-2)
#aLabel=CoMAnalysis.create_text(xA,yA+10,text="A")
#bLabel=CoMAnalysis.create_text(xB,yB+10,text="B")
#cLabel=CoMAnalysis.create_text(xC,yC+10,text="C")
#dLabel=CoMAnalysis.create_text(xD,yD+10,text="D")
#CoMLabel=CoMAnalysis.create_text(xCoM,yCoM+10,text="CoM")
#abLine=CoMAnalysis.create_line(xA,yA,xB,yB,dash=(3,5))
#bcLine=CoMAnalysis.create_line(xB,yB,xC,yC,dash=(3,5))
#adLine=CoMAnalysis.create_line(xA,yA,xD,yD,dash=(3,5))
#CoMAnalysis.grid(row=0,column=0)
TShoulderLabel=tk.Label(modellingUi,text="T_shoulder =")
SLabel=tk.Label(modellingUi,text="S =")
ELabel=tk.Label(modellingUi,text="E =")
timeLabel=tk.Label(modellingUi,text="time =")
CELabel=tk.Label(modellingUi,text="CE =")
anthropometricsButton=tk.Button(modellingUi,text="Anthropometrics Table")
resetButton=tk.Button(modellingUi,text="Reset")
#CoMAnalysis.grid(row=0,column=0)
TShoulderLabel.grid(row=1,column=0)
SLabel.grid(row=2,column=0)
ELabel.grid(row=3,column=0)
timeLabel.grid(row=4,column=0)
CELabel.grid(row=5,column=0)
anthropometricsButton.grid(row=6,column=0)
resetButton.grid(row=7,column=0)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-da9027bed634>", line 153, in onAngleForearmChanged
#     CoMAnalysis.coords(armAnalysis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
# AttributeError: 'int' object has no attribute 'coords'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-da9027bed634>", line 153, in onAngleForearmChanged
#     CoMAnalysis.coords(armAnalysis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
# AttributeError: 'int' object has no attribute 'coords'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
# ...

# %%
#Consumed Endurance GUI draft version 2 -- for debug
import tkinter as tk
from tkinter import ttk
import math as ma

#overall layout
root=tk.Tk()
root.title("Consumed Endurance GUI")
visualizationUi=tk.Frame(root,borderwidth=2,relief=tk.GROOVE)
modellingUi=ttk.Labelframe(root,text="Modelling")
visualizationUi.grid(row=0,column=0,padx=10,pady=20)
modellingUi.grid(row=0,column=1,padx=10,pady=20)

#anthropometrics parameters for arm visualization
ratioAll=0.0025 #real scale / scale in the code
lengthUpperArm=132
lengthForearm=108
lengthHand=76
angleUpperArm=0
angleForearm=0
angleHand=0
ratioCoMUpperArm=0.452
ratioCoMForearm=0.424
ratioCoMHand=0.397
massUpperArm=2.1
massForearm=1.2
massHand=0.4
massxg=(2.1+1.2+0.4)*10
maxTorque=22.94
global xShoulder
xShoulder=10.0
global yShoulder
yShoulder=100.0
global xAPoint
xAPoint=xShoulder*(1-ratioCoMUpperArm)+xElbow*ratioCoMUpperArm
global yAPoint
yAPoint=yShoulder*(1-ratioCoMUpperArm)+yElbow*ratioCoMUpperArm
global xBPoint
xBPoint=xElbow*(1-ratioCoMForearm)+xWrist*ratioCoMForearm
global yBPoint
yBPoint=yElbow*(1-ratioCoMForearm)+yWrist*ratioCoMForearm
global xCPoint
xCPoint=xWrist*(1-ratioCoMHand)+xFingerTip*ratioCoMHand
global yCPoint
yCPoint=yWrist*(1-ratioCoMHand)+yFingerTip*ratioCoMHand
global xDPoint
xDPoint=xBPoint*(1-(massHand/(massForearm+massHand)))+xCPoint*(massHand/(massForearm+massHand))
global yDPoint
yDPoint=yBPoint*(1-(massHand/(massForearm+massHand)))+yCPoint*(massHand/(massForearm+massHand))
global xCoMPoint
xCoMPoint=xAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
global yCoMPoint
yCoMPoint=yAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
global rLength
rLength=ma.sqrt(ma.pow((xCoMPoint-xShoulder),2)+ma.pow((yCoMPoint-yShoulder),2))

#sliders controlling associated limb segment angles
def onAngleUpperArmChanged(val):
    angleUpperArm=float(val)
    angleForearm=float(sliderForearm.get())
    angleHand=float(sliderHand.get())
    global xElbow
    xElbow=xShoulder+lengthUpperArm*ma.cos(angleUpperArm*ma.pi/180)
    global yElbow
    yElbow=yShoulder-lengthUpperArm*ma.sin(angleUpperArm*ma.pi/180)
    global xWrist
    xWrist=xElbow+lengthForearm*ma.cos(angleForearm*ma.pi/180)
    global yWrist
    yWrist=yElbow-lengthForearm*ma.sin(angleForearm*ma.pi/180)
    global xFingerTip
    xFingerTip=xWrist+lengthHand*ma.cos(angleHand*ma.pi/180)
    global yFingerTip
    yFingerTip=yWrist-lengthHand*ma.sin(angleHand*ma.pi/180)
    global xAPoint
    xAPoint=xShoulder*(1-ratioCoMUpperArm)+xElbow*ratioCoMUpperArm
    global yAPoint
    yAPoint=yShoulder*(1-ratioCoMUpperArm)+yElbow*ratioCoMUpperArm
    global xBPoint
    xBPoint=xElbow*(1-ratioCoMForearm)+xWrist*ratioCoMForearm
    global yBPoint
    yBPoint=yElbow*(1-ratioCoMForearm)+yWrist*ratioCoMForearm
    global xCPoint
    xCPoint=xWrist*(1-ratioCoMForearm)+xFingerTip*ratioCoMHand
    global yCPoint
    yCPoint=yWrist*(1-ratioCoMForearm)+yFingerTip*ratioCoMHand
    global xDPoint
    xDPoint=xBPoint*(1-(massHand/(massForearm+massHand)))+xCPoint*(massHand/(massForearm+massHand))
    global yDPoint
    yDPoint=yBPoint*(1-(massHand/(massForearm+massHand)))+yCPoint*(massHand/(massForearm+massHand))
    global xCoMPoint
    xCoMPoint=xAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global yCoMPoint
    yCoMPoint=yAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global rLength
    rLength=ma.sqrt(ma.pow((xCoMPoint-xShoulder),2)+ma.pow((yCoMPoint-yShoulder),2))
    canvasVis.coords(armVis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvasVis.coords(jointElbowVis,xElbow-5,yElbow+5,xElbow+5,yElbow-5)
    canvasVis.coords(jointWristVis,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
    canvasVis.coords(jointFingerTipVis,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    canvasMod.coords(armMod,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvasMod.coords(jointElbowMod,xElbow-5,yElbow+5,xElbow+5,yElbow-5)
    canvasMod.coords(jointWristMod,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
    canvasMod.coords(jointFingerTipMod,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    canvasMod.coords(pointAMod,xAPoint-2,yAPoint+2,xAPoint+2,yAPoint-2)
    canvasMod.coords(pointBMod,xBPoint-2,yBPoint+2,xBPoint+2,yBPoint-2)
    canvasMod.coords(pointCMod,xCPoint-2,yCPoint+2,xCPoint+2,yCPoint-2)
    canvasMod.coords(pointDMod,xDPoint-2,yDPoint+2,xDPoint+2,yDPoint-2)
    canvasMod.coords(pointCoMMod,xCoMPoint-2,yCoMPoint+2,xCoMPoint+2,yCoMPoint-2)
    canvasMod.coords(labelElbowMod,xElbow,yElbow+10)
    canvasMod.coords(labelWristMod,xWrist,yWrist+10)
    canvasMod.coords(labelFingerTipMod,xFingerTip,yFingerTip+10)
    canvasMod.coords(labelAPoint,xAPoint,yAPoint+10)
    canvasMod.coords(labelBPoint,xBPoint,yBPoint+10)
    canvasMod.coords(labelCPoint,xCPoint,yCPoint+10)
    canvasMod.coords(labelDPoint,xDPoint,yDPoint+10)
    canvasMod.coords(labelCoMPoint,xCoMPoint,yCoMPoint+10)
    canvasMod.coords(lineBC,xBPoint,yBPoint,xCPoint,yCPoint)
    canvasMod.coords(lineAD,xAPoint,yAPoint,xDPoint,yDPoint)
    labelTShoulder.config(text="|T_shoulder| (Nm) = %0.2f" %(ratioAll*rLength*massxg))
    labelS.config(text="S (strength) (percentage) = %0.2f" %(100*ratioAll*rLength*massxg/maxTorque))
    labelE.config(text="E (endurance) (second) = %0.2f" %((1236.5/(ma.pow(((100*ratioAll*rLength*massxg/maxTorque)-15),0.618)))-72.5))

def onAngleForearmChanged(val):
    angleForearm=float(val)
    angleHand=float(sliderHand.get())
    global xWrist
    xWrist=xElbow+lengthForearm*ma.cos(angleForearm*ma.pi/180)
    global yWrist
    yWrist=yElbow-lengthForearm*ma.sin(angleForearm*ma.pi/180)
    global xFingerTip
    xFingerTip=xWrist+lengthHand*ma.cos(angleHand*ma.pi/180)
    global yFingerTip
    yFingerTip=yWrist-lengthHand*ma.sin(angleHand*ma.pi/180)
    global xBPoint
    xBPoint=xElbow*(1-ratioCoMForearm)+xWrist*ratioCoMForearm
    global yBPoint
    yBPoint=yElbow*(1-ratioCoMForearm)+yWrist*ratioCoMForearm
    global xCPoint
    xCPoint=xWrist*(1-ratioCoMForearm)+xFingerTip*ratioCoMHand
    global yCPoint
    yCPoint=yWrist*(1-ratioCoMForearm)+yFingerTip*ratioCoMHand
    global xDPoint
    xDPoint=xBPoint*(1-(massHand/(massForearm+massHand)))+xCPoint*(massHand/(massForearm+massHand))
    global yDPoint
    yDPoint=yBPoint*(1-(massHand/(massForearm+massHand)))+yCPoint*(massHand/(massForearm+massHand))
    global xCoMPoint
    xCoMPoint=xAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global yCoMPoint
    yCoMPoint=yAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global rLength
    rLength=ma.sqrt(ma.pow((xCoMPoint-xShoulder),2)+ma.pow((yCoMPoint-yShoulder),2))
    canvasVis.coords(armVis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvasVis.coords(jointWristVis,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
    canvasVis.coords(jointFingerTipVis,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    canvasMod.coords(armMod,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvasMod.coords(jointWristMod,xWrist-5,yWrist+5,xWrist+5,yWrist-5)
    canvasMod.coords(jointFingerTipMod,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    canvasMod.coords(pointBMod,xBPoint-2,yBPoint+2,xBPoint+2,yBPoint-2)
    canvasMod.coords(pointCMod,xCPoint-2,yCPoint+2,xCPoint+2,yCPoint-2)
    canvasMod.coords(pointDMod,xDPoint-2,yDPoint+2,xDPoint+2,yDPoint-2)
    canvasMod.coords(pointCoMMod,xCoMPoint-2,yCoMPoint+2,xCoMPoint+2,yCoMPoint-2)
    canvasMod.coords(labelWristMod,xWrist,yWrist+10)
    canvasMod.coords(labelFingerTipMod,xFingerTip,yFingerTip+10)
    canvasMod.coords(labelBPoint,xBPoint,yBPoint+10)
    canvasMod.coords(labelCPoint,xCPoint,yCPoint+10)
    canvasMod.coords(labelDPoint,xDPoint,yDPoint+10)
    canvasMod.coords(labelCoMPoint,xCoMPoint,yCoMPoint+10)
    canvasMod.coords(lineBC,xBPoint,yBPoint,xCPoint,yCPoint)
    canvasMod.coords(lineAD,xAPoint,yAPoint,xDPoint,yDPoint)
    labelTShoulder.config(text="|T_shoulder| (Nm) = %0.2f" %(ratioAll*rLength*massxg))
    labelS.config(text="S (strength) (percentage) = %0.2f" %(100*ratioAll*rLength*massxg/maxTorque))
    labelE.config(text="E (endurance) (second) = %0.2f" %((1236.5/(ma.pow(((100*ratioAll*rLength*massxg/maxTorque)-15),0.618)))-72.5))

def onAngleHandChanged(val):
    angleHand=float(val)
    global xFingerTip
    xFingerTip=xWrist+lengthHand*ma.cos(angleHand*ma.pi/180)
    global yFingerTip
    yFingerTip=yWrist-lengthHand*ma.sin(angleHand*ma.pi/180)
    global xCPoint
    xCPoint=xWrist*(1-ratioCoMForearm)+xFingerTip*ratioCoMHand
    global yCPoint
    yCPoint=yWrist*(1-ratioCoMForearm)+yFingerTip*ratioCoMHand
    global xDPoint
    xDPoint=xBPoint*(1-(massHand/(massForearm+massHand)))+xCPoint*(massHand/(massForearm+massHand))
    global yDPoint
    yDPoint=yBPoint*(1-(massHand/(massForearm+massHand)))+yCPoint*(massHand/(massForearm+massHand))
    global xCoMPoint
    xCoMPoint=xAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+xDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global yCoMPoint
    yCoMPoint=yAPoint*(1-((massForearm+massHand)/(massUpperArm+massForearm+massHand)))+yDPoint*((massForearm+massHand)/(massUpperArm+massForearm+massHand))
    global rLength
    rLength=ma.sqrt(ma.pow((xCoMPoint-xShoulder),2)+ma.pow((yCoMPoint-yShoulder),2))
    canvasVis.coords(armVis,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvasVis.coords(jointFingerTipVis,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    canvasMod.coords(armMod,xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
    canvasMod.coords(jointFingerTipMod,xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
    canvasMod.coords(pointCMod,xCPoint-2,yCPoint+2,xCPoint+2,yCPoint-2)
    canvasMod.coords(pointDMod,xDPoint-2,yDPoint+2,xDPoint+2,yDPoint-2)
    canvasMod.coords(pointCoMMod,xCoMPoint-2,yCoMPoint+2,xCoMPoint+2,yCoMPoint-2)
    canvasMod.coords(labelFingerTipMod,xFingerTip,yFingerTip+10)
    canvasMod.coords(labelCPoint,xCPoint,yCPoint+10)
    canvasMod.coords(labelDPoint,xDPoint,yDPoint+10)
    canvasMod.coords(labelCoMPoint,xCoMPoint,yCoMPoint+10)
    canvasMod.coords(lineBC,xBPoint,yBPoint,xCPoint,yCPoint)
    canvasMod.coords(lineAD,xAPoint,yAPoint,xDPoint,yDPoint)
    labelTShoulder.config(text="|T_shoulder| (Nm) = %0.2f" %(ratioAll*rLength*massxg))
    labelS.config(text="S (strength) (percentage) = %0.2f" %(100*ratioAll*rLength*massxg/maxTorque))
    labelE.config(text="E (endurance) (second) = %0.2f" %((1236.5/(ma.pow(((100*ratioAll*rLength*massxg/maxTorque)-15),0.618)))-72.5))


def onResetClicked(event):
    sliderUpperArm.set(0)
    sliderForearm.set(0)
    sliderHand.set(0)

#visualization (Vis) UI
canvasVis=tk.Canvas(visualizationUi,bg="white",borderwidth=2,relief=tk.GROOVE)
armVis=canvasVis.create_line(xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
jointShoulderVis=canvasVis.create_oval(xShoulder-5,yShoulder+5,xShoulder+5,yShoulder-5)
jointElbowVis=canvasVis.create_oval(xElbow-5,yElbow+5,xElbow+5,yElbow-5)
jointWristVis=canvasVis.create_oval(xWrist-5,yWrist+5,xWrist+5,yWrist-5)
jointFingerTipVis=canvasVis.create_oval(xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
sliderUpperArm=tk.Scale(visualizationUi,from_=90,to=-90,command=onAngleUpperArmChanged)
sliderForearm=tk.Scale(visualizationUi,from_=90,to=0,command=onAngleForearmChanged)
sliderHand=tk.Scale(visualizationUi,from_=90,to=-90,command=onAngleHandChanged)
labelAngleUpperArm=tk.Label(visualizationUi,text="Upper Arm Angle (°) =")
labelAngleForearm=tk.Label(visualizationUi,text="Forearm Angle (°) =")
labelAngleHand=tk.Label(visualizationUi,text="Hand Angle (°) =")
canvasVis.grid(row=0,column=0,columnspan=3,padx=10,pady=10)
sliderUpperArm.grid(row=1,column=0)
sliderForearm.grid(row=1,column=1)
sliderHand.grid(row=1,column=2)
labelAngleUpperArm.grid(row=2,column=0)
labelAngleForearm.grid(row=2,column=1)
labelAngleHand.grid(row=2,column=2)

#modelling UI
canvasMod=tk.Canvas(modellingUi,borderwidth=2,relief=tk.GROOVE)
armMod=canvasMod.create_line(xShoulder,yShoulder,xElbow,yElbow,xWrist,yWrist,xFingerTip,yFingerTip)
jointShoulderMod=canvasMod.create_oval(xShoulder-5,yShoulder+5,xShoulder+5,yShoulder-5)
jointElbowMod=canvasMod.create_oval(xElbow-5,yElbow+5,xElbow+5,yElbow-5)
jointWristMod=canvasMod.create_oval(xWrist-5,yWrist+5,xWrist+5,yWrist-5)
jointFingerTipMod=canvasMod.create_oval(xFingerTip-5,yFingerTip+5,xFingerTip+5,yFingerTip-5)
pointAMod=canvasMod.create_oval(xAPoint-2,yAPoint+2,xAPoint+2,yAPoint-2)
pointBMod=canvasMod.create_oval(xBPoint-2,yBPoint+2,xBPoint+2,yBPoint-2)
pointCMod=canvasMod.create_oval(xCPoint-2,yCPoint+2,xCPoint+2,yCPoint-2)
pointDMod=canvasMod.create_oval(xDPoint-2,yDPoint+2,xDPoint+2,yDPoint-2)
pointCoMMod=canvasMod.create_oval(xCoMPoint-2,yCoMPoint+2,xCoMPoint+2,yCoMPoint-2)
lineBC=canvasMod.create_line(xBPoint,yBPoint,xCPoint,yCPoint,dash=(3,5))
lineAD=canvasMod.create_line(xAPoint,yAPoint,xDPoint,yDPoint,dash=(3,5))
labelShoulderMod=canvasMod.create_text(xShoulder,yShoulder+10,text="Shoulder")
labelElbowMod=canvasMod.create_text(xElbow,yElbow+10,text="Elbow")
labelWristMod=canvasMod.create_text(xWrist,yWrist+10,text="Wrist")
labelFingerTipMod=canvasMod.create_text(xFingerTip,yFingerTip+10,text="Finger Tip")
labelAPoint=canvasMod.create_text(xAPoint,yAPoint+10,text="A")
labelBPoint=canvasMod.create_text(xBPoint,yBPoint+10,text="B")
labelCPoint=canvasMod.create_text(xCPoint,yCPoint+10,text="C")
labelDPoint=canvasMod.create_text(xDPoint,yDPoint+10,text="D")
labelCoMPoint=canvasMod.create_text(xCoMPoint,yCoMPoint,text="CoM")
labelTShoulder=tk.Label(modellingUi,text="|T_shoulder| (Nm) = %0.2f" %(ratioAll*rLength*massxg))
labelS=tk.Label(modellingUi,text="S (strength) (percentage) = %0.2f" %(100*ratioAll*rLength*massxg/maxTorque))
labelE=tk.Label(modellingUi,text="E (endurance) (second) = %0.2f" %((1236.5/(ma.pow(((100*ratioAll*rLength*massxg/maxTorque)-15),0.618)))-72.5))
buttonTable=tk.Button(modellingUi,text="Anthropometrics Table")
buttonReset=tk.Button(modellingUi,text="Reset",bg='#007ac9',fg="white")
canvasMod.grid(row=0,column=0,columnspan=2,padx=10,pady=10)
labelTShoulder.grid(row=1,column=0)
labelS.grid(row=2,column=0)
labelE.grid(row=3,column=0)
buttonTable.grid(row=4,column=0,pady=10)
buttonReset.grid(row=5,column=0,pady=10)
buttonReset.bind('<Button-1>',onResetClicked)

root.mainloop()
